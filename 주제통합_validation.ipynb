# %%
import zipfile
import os
import json
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## 최종 코드

# %% [markdown]
# ### 10개 주제 하나의 파일로 통합

# %%
import json
import os
import pandas as pd
import csv

#path = 'C:\\Users\\wf34fg\\python\\NHN_범죄수사\\01.news_r\\2~3sent\\'
path= 'C:\\Users\\wf34fg\\python\\NHN_범죄수사\\생성모델링\\all_valid\\'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.json')]

print(file_list_py)

n = len(file_list_py)

df = pd.DataFrame({'passage':[],'summary1':[],'summary2':[],'summary3':[],'summmary_3_cnt':[]})

print(df)

col = ["passage", "summary1","summary2","summary3"]

for i in range(n):
    li = []
    file = open(file_list_py[i],encoding='UTF-8')
    jsonString = json.load(file)
    #print(jsonString.get("Annotation").get("summary1"))
    li.append(jsonString.get("Meta(Refine)").get("passage"))
    li.append(jsonString.get("Annotation").get("summary1"))
    li.append(jsonString.get("Annotation").get("summary2"))
    li.append(jsonString.get("Annotation").get("summary3"))
    li.append(jsonString.get("Annotation").get("summary_3_cnt"))
    df.loc[i] = li
    #re.append(df)

print(df)

#print(re[0])
# Out:
# ['REPORT-briefing-51279-00001.json', 'REPORT-briefing-51307-00001.json', 'REPORT-briefing-51309-00002.json', 'REPORT-briefing-51310-00001.json', 'REPORT-briefing-51448-00001.json', 'REPORT-briefing-51500-00001.json', 'REPORT-briefing-51597-00001.json', 'REPORT-briefing-51620-00002.json', 'REPORT-briefing-51685-00001.json', 'REPORT-briefing-51696-00001.json', 'REPORT-briefing-51750-00001.json', 'REPORT-briefing-51772-00002.json', 'REPORT-briefing-51840-00016.json', 'REPORT-briefing-51938-00002.json', 'REPORT-briefing-51941-00001.json', 'REPORT-briefing-51973-00008.json', 'REPORT-briefing-52064-00002.json', 'REPORT-briefing-52176-00001.json', 'REPORT-briefing-52184-00001.json', 'REPORT-briefing-52185-00001.json', 'REPORT-briefing-52233-00001.json', 'REPORT-briefing-52317-00001.json', 'REPORT-briefing-52336-00001.json', 'REPORT-briefing-52354-00002.json', 'REPORT-briefing-52360-00003.json', 'REPORT-briefing-52407-00001.json', 'REPORT-briefing-52415-00002.json', 'REPORT-briefing-52490-00001.json', 'REPORT-briefing-52491-00001.json', 'REPORT-briefing-52531-00001.json', 'REPORT-briefing-52691-00002.json', 'REPORT-briefing-52765-00001.json', 'REPORT-briefing-52775-00001.json', 'REPORT-briefing-52874-00001.json', 'REPORT-briefing-52883-00001.json', 'REPORT-briefing-52918-00001.json', 'REPORT-briefing-52939-00001.json', 'REPORT-briefing-53021-00001.json', 'REPORT-briefing-53107-00001.json', 'REPORT-briefing-53292-00001.json', 'REPORT-briefing-53361-00001.json', 'REPORT-briefing-53457-00001.json', 'REPORT-briefing-53470-00001.json', 'REPORT-briefing-53482-00002.json', 'REPORT-briefing-53498-00001.json', 'REPORT-briefing-53503-00001.json', 'REPORT-briefing-53618-00001.json', 'REPORT-briefing-53623-00001.json', 'REPORT-briefing-53635-00001.json', 'REPORT-
# 9146  다음은 예방접종증명서의 활용과 위·변조와 관련된 주의·당부입니다. 코로나19 예방접...
# 9147  금요일 발표 내용은 사회적 거리두기 조정에 대한 내용이기 때문에 의료체계에 대한 내...
# 9148  안녕하십니까? 해양수산부 수산정책실장 김준석입니다. 오늘 브리핑은 어촌지역 활성화 ...
# 9149  또한, 한국판 그린뉴딜, 2050 탄소중립 등 국가 전략을 뒷받침하고, 갯벌의 지속...
#
#                                                summary1  \
# 0     소방청은 국가직으로 신분이 전환된 소방공무원을 85명 임용했으며 이들은 충남소방 현...
# 1     기획재정부가 감염병 대응 조직체계 구축, 의료진 역량 강화 등을 위해 방글라데시에 ...
# 2     EDCF와 AfDB는 수원국 정부의 효율적인 정책집행을 위한 관리와 성과관리를 위한...
# 3     소방청은 전국적으로 여성 소방공무원이 대형특수소방차 운전요원으로 활동하고 있다고 밝...
# 4     소방청은 2020년도 공공기관 청렴도 평가에서 종합청렴도 2등급을 받았고 신 소방청...
# ...                                                 ...
# 9145  야구장·축구장 등 임대 체육시설의 경우에는 사적모임 제한 때문에 사실상 영업이 매우...
# 9146  코로나19 예방접종증명서의 활용이 늘 것으로 예상되며 다중이용시설에서 위·변조한 증...
# 9147  의료체계의 대응 여력으로 볼 때 위중증률과 치명률이 중요한 지표이며 입원 기간의 단...
# 9148  해양수산부에서는 어촌지역 활성화 대책을 마련하여 어촌지역으로 신규인력의 유입을 촉진...
# 9149  한국판 그린뉴딜과 2050 탄소중립 등 국가 전략을 뒷받침하고 갯벌의 지속가능한 경...
#
#                                                summary2 summary3  \
# 0     소방청(청장 정문호)은 4월 1일 시행되는 소방공무원 신분 국가직화에 따라 85명의...     None
# 1     기획재정부는 개도국의 코로나19 효과적 대응을 위해 10월 14일 필리핀캄보디아에 ...     None
# 2     한편, EDCF와 AfDB는 수원국 정부의 효율적인 정책집행을 뒷받침하기 위해 동 ...     None
# 3     소방청(청장 정문호)은 전국적으로 48명의 여성 소방공무원이 대형특수소방차 운전요원...     None
# 4     소방청(청장 신열우)은 9일 국민권익위원회에서 발표한‘2020년도 공공기관 청렴도 ...     None
# ...                                                 ...      ...
# 9145  야구장·축구장 등 임대 체육시설의 경우에는 사적모임의 제한 때문에 사실상 영업이 매...     None
# 9146  코로나19 예방접종률이 높아지고 단계적 일상회복에 대한 논의가 진행되면서 예방접종증...     None
# 9147  따라서 이러한 부분들에 대해서는 입원 기간의 단축이나 재택치료의 확대 등을 통해서 ...     None
# 9148  해양수산부에서는 인구감소와 고령화로 인한 어촌지역 소멸을 방지하고 활기찬 어촌을 만...     None
# 9149  또한, 한국판 그린뉴딜, 2050 탄소중립 등 국가 전략을 뒷받침하고, 갯벌의 지속...     None
#
#      summmary_3_cnt
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 9145           None
# 9146           None
# 9147           None
# 9148           None
# 9149           None
#
# [9150 rows x 5 columns]

# %%
df.to_csv("주제통합_valid.csv", encoding='utf-8-sig')
